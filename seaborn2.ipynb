# %% [markdown]
# we use distribution plots to visualize the distribution of quantitative data .
#
# lets discuss some plots that allow us to visualize the distribution of data set .these plots are:
#
# > displot/histplot
# > joinplot
# > pairplot
# > rugplot

# %% [markdown]
# seaborn in python liberary

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df1=sns.displot(df['total_bill'],bins=100)
df1

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins=20,kde='True')
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=20,kde='True')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind="reg")

# %%
sns.jointplot(x='total_bill',y="tip",data=df,kind="scatter")

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind="hex")

# %%
sns.pairplot(df,hue='size',palette='rainbow')

# %%
df=sns.pairplot(df,hue='sex',palette='rainbow')
df.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(df)
# Out:
# <Axes: >

# %% [markdown]
# Categorical Data plots
#
# NOw let discuss using seaborn to plot categorical data  there are a few main plots types for this.
#
# . boxplot
# . violinplot
# . stripplot
# . swarmplot
# . barplot
# . countplot
#
# lets go through example of each

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x=df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(y=df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.barplot(x=df['sex'],y=df['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# You can change the estimater obj to your own function ,that convert a vector to a scalar.
# mean(default):np.mean
# sum: np.sum
# count:len(to count the num of observation )
# standard deviation : np.std
# minimum : np.min
# maximum : np.max

# %%
import  numpy as np
sns.barplot(x=df['sex'],y=df['total_bill'],estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# Boxplot

# %%
sns.boxplot(x='tip',y='day',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# boxplot and violin plot
#
# boxplot and violinplot boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be "outliers" using a method that is a function of the inter-quartile range.
