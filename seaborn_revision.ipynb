# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('bike_price_synthetic[2].csv')
df
# Out:
#         num_cont1  num_cont2  num_cont3  num_cont4  num_cont5  num_cont6  \
# 0       47.087495  47.911030  39.339070  74.501104  73.233196  43.799596
# 1       55.150330  67.597670  48.622579  70.397091  36.073411  54.118096
# 2       91.141949  27.291724  53.903007  43.245123  76.575898  62.490961
# 3       59.607197  43.977423  61.770837  57.471861  57.614104  44.300982
# 4       61.784334  49.744105  49.434253  67.653519  70.160608  72.702186
# ...           ...        ...        ...        ...        ...        ...
# 100495  33.839895  41.303850  53.684001  66.732618  60.218505  60.405479
# 100496  50.708981  54.953115  54.935936  56.454997  78.227934  56.917731
# 100497  63.181130  38.364399  72.472564  67.641272  49.966005  53.307319
# 100498  61.296157  47.950444  47.359091  15.315531  82.608265  31.016401
# 100499  50.822280  28.151501  25.750507  37.688340  57.195927  72.916846
#
#         num_cont7  num_cont8   mileage_k  service_count  ...  condition  \
# ...

# %%
df.head()
# Out:
#    num_cont1  num_cont2  num_cont3  num_cont4  num_cont5  num_cont6  \
# 0  47.087495  47.911030  39.339070  74.501104  73.233196  43.799596
# 1  55.150330  67.597670  48.622579  70.397091  36.073411  54.118096
# 2  91.141949  27.291724  53.903007  43.245123  76.575898  62.490961
# 3  59.607197  43.977423  61.770837  57.471861  57.614104  44.300982
# 4  61.784334  49.744105  49.434253  67.653519  70.160608  72.702186
#
#    num_cont7  num_cont8   mileage_k  service_count  ...  condition     brand  \
# 0  20.240487  53.772187  149.512703              4  ...        3.0     Honda
# 1  53.888309  47.671382   21.431336              2  ...        4.0    Yamaha
# 2  17.454884  74.906340  177.749964              0  ...        2.0     Honda
# 3  29.037608  48.562269  106.504123              3  ...        4.0    Yamaha
# 4  25.975173  89.926042  120.690863              5  ...        2.0  Kawasaki
#
#    fuel_type bike_type  color seller_type model_name     seller_notes  \
# ...

# %% [markdown]
# 1.
# Understand how bike features (e.g., mileage, brand, engine specs, condition) influence price.

# %%
sns.scatterplot(data=df,x='mileage_k',y='price',hue='brand')
# Out:
# <Axes: xlabel='mileage_k', ylabel='price'>

# %%
sns.scatterplot(data=df,x='brand',y='price',hue='brand')
# Out:
# <Axes: xlabel='brand', ylabel='price'>

# %%
df1=pd.read_csv('bike_price_synthetic_data.csv')
df1
# Out:
#         num_cont1  num_cont2  num_cont3  num_cont4  num_cont5  num_cont6  \
# 0       47.087495  47.911030  39.339070  74.501104  73.233196  43.799596
# 1       55.150330  67.597670  48.622579  70.397091  36.073411  54.118096
# 2       91.141949  27.291724  53.903007  43.245123  76.575898  62.490961
# 3       59.607197  43.977423  61.770837  57.471861  57.614104  44.300982
# 4       61.784334  49.744105  49.434253  67.653519  70.160608  72.702186
# ...           ...        ...        ...        ...        ...        ...
# 100495  33.839895  41.303850  53.684001  66.732618  60.218505  60.405479
# 100496  50.708981  54.953115  54.935936  56.454997  78.227934  56.917731
# 100497  63.181130  38.364399  72.472564  67.641272  49.966005  53.307319
# 100498  61.296157  47.950444  47.359091  15.315531  82.608265  31.016401
# 100499  50.822280  28.151501  25.750507  37.688340  57.195927  72.916846
#
#         num_cont7  num_cont8   mileage_k  service_count  ...  condition  \
# ...

# %% [markdown]
# 1.
# Understand how bike features (e.g., mileage, brand, engine specs, condition) influence price

# %%
sns.relplot(data=df,x='mileage_k',y='price',hue='brand',kind='scatter')

# %%
sns.relplot(data=df,x='mileage_k',y='price',hue='brand',kind='line')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.relplot(data=df,x='mileage_k',y='price',hue='brand',kind='line')
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\relational.py:838, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     829 g = FacetGrid(
#     830     data=full_data.dropna(axis=1, how="all"),
#     831     **grid_kws,
#    (...)
#     834     **facet_kws
#     835 )
#     837 # Draw the plot
# --> 838 g.map_dataframe(func, **plot_kws)
#     840 # Label the axes, using the original variables
#     841 # Pass "" when the variable name is None to overwrite internal variables
# ...

# %%
sns.displot(data=df,x='mileage_k',y='price',hue='brand',kind='hist')

# %%
sns.displot(data=df,x='mileage_k',y='price',hue='brand',kind='ecdf')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.displot(data=df,x='mileage_k',y='price',hue='brand',kind='ecdf')
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2246, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2242         p.plot_univariate_ecdf(**ecdf_kws)
#    2244     else:
# -> 2246         raise NotImplementedError("Bivariate ECDF plots are not implemented")
#    2248 # All plot kinds can include a rug
#    2249 if rug:
#    2250     # TODO with expand_margins=True, each facet expands margins... annoying!
#
# NotImplementedError: Bivariate ECDF plots are not implemented

# %%
sns.displot(data=df,x='mileage_k',y='price',hue='brand',kind='kde')
