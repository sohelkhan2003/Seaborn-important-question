# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 42        13.94  3.06    Male     No   Sun  Dinner     2
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 119       24.08  2.92  Female     No  Thur   Lunch     4
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2
# 108       18.24  3.76    Male     No   Sat  Dinner     2
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# RElplot -> fig level fun

# %%
import plotly.express as px

# %%
df1=px.data.gapminder()

# %%
df1
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df1.head(2)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030       AFG
#
#    iso_num
# 0        4
# 1        4

# %%
i_df=df1[df1['country']=='India']
i_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
sns.lineplot(data=i_df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
temp_df=df1[df1['country'].isin(['India','Spain','Brazil'])]
temp_df
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
sns.lineplot(data=temp_df,x='year',y='lifeExp',hue='country',style='continent',size='iso_num')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.lineplot(data=temp_df,x='year',y='lifeExp',hue='country',size='continent',style='iso_num')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(kind='line',data=temp_df,x='year',y='lifeExp',hue='country',style='continent',row='iso_num',col='iso_alpha')

# %%
sns.relplot(kind='scatter',data=temp_df,x='year',y='lifeExp',hue='country',style='continent',row='iso_num',col='iso_alpha')

# %% [markdown]
# Distribution plot

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(kind='hist',data=df,x='total_bill',bins= 20)

# %%
sns.displot(kind='hist',data=df,x='day')

# %%
sns.displot(kind='hist',data=df,x='tip',hue='sex')

# %% [markdown]
# KDE kernal density

# %%
sns.displot(kind='kde',data=df,x='tip',hue='sex',fill=True)

# %%
country_df=px.data.gapminder()

# %%
df2=country_df.select_dtypes(exclude='object').corr()

# %% [markdown]
# CATEGORICAL PLOT

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# that is nothing but where 1

# %%
sns.stripplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=df,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=df,x='day',y='total_bill',kind='strip')

# %% [markdown]
# striop plit  or catplot work
# data distribution are both
#
# strip plot allow point overlap data when mainy point
#
# clarity
# strip plot may be very small to medidum to small data set

# %%
sns.catplot(data=df,x='day',y='total_bill',kind='strip')

# %% [markdown]
# violinplot
#
# kernal density plot
#
# violinplot plot is nothing but box plot and kernaldensity plot to show the distribution plot  or variance
#
# 1.it flow the data are max and mix value
# 2. central  tendency
# 3. the curve safe display

# %%
sns.violinplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df[df['day']=='Sat']['total_bill'].max(),df[df['day']=='Sat']['total_bill'].min()
# Out:
# (np.float64(50.81), np.float64(3.07))

# %%
df[df['day']=='Thur']['total_bill'].max(),df[df['day']=='Thur']['total_bill'].min()
# Out:
# (np.float64(43.11), np.float64(7.51))

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# 1.barplot()
#
# the upper black are know as errorbar

# %%
sns.barplot(data=df,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
df.groupby('sex')['total_bill'].max(),df.groupby('sex')['total_bill'].min()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24596\93818264.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['total_bill'].max(),df.groupby('sex')['total_bill'].min()
# (sex
#  Male      50.81
#  Female    44.30
#  Name: total_bill, dtype: float64,
#  sex
#  Male      7.25
#  Female    3.07
#  Name: total_bill, dtype: float64)

# %%
df.groupby('sex')['total_bill'].count()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24596\992924662.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['total_bill'].count()
# sex
# Male      157
# Female     87
# Name: total_bill, dtype: int64

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24596\3379495421.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['total_bill'].mean()
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
sns.barplot(data=df,x='sex',y='total_bill',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.pointplot(data=df,x='sex',y='total_bill',errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# catplot
sns.catplot(data=df,x='sex',y='total_bill',kind='bar',col='smoker',row='time')

# %% [markdown]
# Regration plot
#
# ->primary
# 1. regplot
# 2.implot

# %%
sns.regplot(data=df,x='total_bill',y='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.regplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.residplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
